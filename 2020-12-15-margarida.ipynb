# %% [markdown]
# <a href="https://colab.research.google.com/github/Veroberg/repo_colorization/blob/main/2020-12-15-margarida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#hide
# !wget https://i.pinimg.com/564x/87/75/aa/8775aa47de3a6beecd537291572552a2.jpg
# Out:
# --2020-12-15 14:15:33--  https://i.pinimg.com/564x/87/75/aa/8775aa47de3a6beecd537291572552a2.jpg
# Resolving i.pinimg.com (i.pinimg.com)... 104.18.15.176, 104.18.14.176, 2a04:4e42:9::84
# Connecting to i.pinimg.com (i.pinimg.com)|104.18.15.176|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38747 (38K) [image/jpeg]
# Saving to: ‘8775aa47de3a6beecd537291572552a2.jpg’
#
# 8775aa47de3a6beecd5 100%[===================>]  37.84K  --.-KB/s    in 0s
#
# 2020-12-15 14:15:33 (125 MB/s) - ‘8775aa47de3a6beecd537291572552a2.jpg’ saved [38747/38747]

# %% [markdown]
# # "Flor Margarida"
# > Colorização da imagem da Flor Margarida usando a rede neural DeOldify
#
# - toc: false
# - branch: master
# - badges: true
# - comments: true
# - categories: [natureza]

# %%
#hide
# !wget https://raw.githubusercontent.com/awarischool/br-data-science/master/image-colorizer/deoldify_wrapper.py
# Out:
# --2020-12-15 14:16:04--  https://raw.githubusercontent.com/awarischool/br-data-science/master/image-colorizer/deoldify_wrapper.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2623 (2.6K) [text/plain]
# Saving to: ‘deoldify_wrapper.py’
#
# deoldify_wrapper.py 100%[===================>]   2.56K  --.-KB/s    in 0s
#
# 2020-12-15 14:16:04 (49.2 MB/s) - ‘deoldify_wrapper.py’ saved [2623/2623]

# %%
#hide
from deoldify_wrapper import DeOldify

# %%
#hide
deo = DeOldify ()
# Out:
#   Initializing Colorizer
# /usr/local/lib/python3.6/dist-packages/fastai/data_block.py:442: UserWarning: Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.
#   warn("Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.")
# /usr/local/lib/python3.6/dist-packages/fastai/data_block.py:445: UserWarning: Your validation set is empty. If this is by design, use `split_none()`
#                  or pass `ignore_empty=True` when labelling to remove this warning.
#   or pass `ignore_empty=True` when labelling to remove this warning.""")
# Downloading: "https://download.pytorch.org/models/resnet101-5d3b4d8f.pth" to /root/.cache/torch/hub/checkpoints/resnet101-5d3b4d8f.pth
# ...
# Done!

# %%
#hide_input
deo.colorize("https://i.pinimg.com/564x/87/75/aa/8775aa47de3a6beecd537291572552a2.jpg")
